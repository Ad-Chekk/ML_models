# %% [markdown]
# <a href="https://colab.research.google.com/github/Ad-Chekk/ML_models/blob/main/Obstacle_game_RL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygame torch torchvision numpy
# Out:
# Requirement already satisfied: pygame in /usr/local/lib/python3.11/dist-packages (2.6.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)

# %%
def preprocess(frame):
    frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)  # Convert to grayscale
    frame = cv2.resize(frame, (84, 84)) / 255.0      # Resize & normalize

    # ✅ Apply a color effect (Invert colors)
    frame = 1.0 - frame  # This makes the game appear like "negative film"

    return frame

# %%
# !pip install gymnasium[atari] ale-py AutoROM opencv-python torch torchvision
# !AutoROM --accept-license --install-dir /root/.roms
import os
os.environ["ALE_ROM_PATH"] = "/root/.roms"
# Out:
# Requirement already satisfied: ale-py in /usr/local/lib/python3.11/dist-packages (0.10.2)
# Requirement already satisfied: AutoROM in /usr/local/lib/python3.11/dist-packages (0.6.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: gymnasium[atari] in /usr/local/lib/python3.11/dist-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (0.0.4)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from AutoROM) (8.1.8)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from AutoROM) (2.32.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->AutoROM) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->AutoROM) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->AutoROM) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->AutoROM) (2025.1.31)
# Usage: AutoROM [OPTIONS]
# Try 'AutoROM --help' for help.
#
# Error: Invalid value for '-d' / '--install-dir': Path '/root/.roms' does not exist.

# %%
import pygame
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from collections import deque

# Game Constants
SCREEN_WIDTH, SCREEN_HEIGHT = 400, 600
PLAYER_SIZE = 40
BLOCK_SIZE = 40
BLOCK_SPEED = 5
FPS = 30

# Initialize Pygame
pygame.init()
screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
clock = pygame.time.Clock()

class DodgeGame:
    def __init__(self):
        self.reset()

    def reset(self):
        self.player_x = SCREEN_WIDTH // 2 - PLAYER_SIZE // 2
        self.player_y = SCREEN_HEIGHT - 80
        self.blocks = []
        self.score = 0
        return self.get_state()

    def step(self, action):
        # Move Left or Right
        if action == 0:
            self.player_x -= 20
        elif action == 1:
            self.player_x += 20

        # Keep player within screen
        self.player_x = max(0, min(self.player_x, SCREEN_WIDTH - PLAYER_SIZE))

        # Move blocks down
        for block in self.blocks:
            block[1] += BLOCK_SPEED

        # Remove blocks that leave screen
        self.blocks = [b for b in self.blocks if b[1] < SCREEN_HEIGHT]

        # Spawn new blocks randomly
        if random.random() < 0.05:
            self.blocks.append([random.randint(0, SCREEN_WIDTH - BLOCK_SIZE), 0])

        # Check for collision
        for bx, by in self.blocks:
            if (bx < self.player_x < bx + BLOCK_SIZE or bx < self.player_x + PLAYER_SIZE < bx + BLOCK_SIZE) and (by + BLOCK_SIZE > self.player_y):
                return self.get_state(), -10, True  # Game Over

        self.score += 1
        return self.get_state(), 1, False  # Reward for surviving

    def get_state(self):
        state = np.zeros((SCREEN_WIDTH, SCREEN_HEIGHT))
        state[self.player_x:self.player_x + PLAYER_SIZE, self.player_y:self.player_y + PLAYER_SIZE] = 1
        for bx, by in self.blocks:
            state[bx:bx + BLOCK_SIZE, by:by + BLOCK_SIZE] = -1
        return torch.tensor(state, dtype=torch.float32).flatten()

    def render(self):
        screen.fill((30, 30, 30))  # Background
        pygame.draw.rect(screen, (0, 255, 0), (self.player_x, self.player_y, PLAYER_SIZE, PLAYER_SIZE))  # Player
        for bx, by in self.blocks:
            pygame.draw.rect(screen, (255, 0, 0), (bx, by, BLOCK_SIZE, BLOCK_SIZE))  # Falling blocks
        pygame.display.flip()
        clock.tick(FPS)

# %%
class DQN(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(DQN, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, output_dim)
        )

    def forward(self, x):
        return self.fc(x)

# Initialize Game & DQN
env = DodgeGame()
state_dim = SCREEN_WIDTH * SCREEN_HEIGHT
action_dim = 2  # Left or Right

policy_net = DQN(state_dim, action_dim)
target_net = DQN(state_dim, action_dim)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = optim.Adam(policy_net.parameters(), lr=0.001)
loss_fn = nn.MSELoss()
memory = deque(maxlen=5000)
gamma = 0.99
epsilon = 1.0
epsilon_min = 0.05
epsilon_decay = 0.995
batch_size = 32
update_target_freq = 10

def select_action(state):
    if random.random() < epsilon:
        return random.choice([0, 1])  # Random action
    else:
        with torch.no_grad():
            return policy_net(state).argmax().item()

# Training loop
num_episodes = 500
for episode in range(num_episodes):
    state = env.reset()
    total_reward = 0
    done = False

    while not done:
        action = select_action(state)
        next_state, reward, done = env.step(action)

        memory.append((state, action, reward, next_state, done))
        state = next_state
        total_reward += reward

        if done:
            break

    if len(memory) > batch_size:
        minibatch = random.sample(memory, batch_size)
        states, actions, rewards, next_states, dones = zip(*minibatch)

        states = torch.stack(states)
        actions = torch.tensor(actions, dtype=torch.int64)
        rewards = torch.tensor(rewards, dtype=torch.float32)
        next_states = torch.stack(next_states)
        dones = torch.tensor(dones, dtype=torch.float32)

        q_values = policy_net(states).gather(1, actions.unsqueeze(1)).squeeze()
        next_q_values = target_net(next_states).max(1)[0].detach()
        expected_q_values = rewards + gamma * next_q_values * (1 - dones)

        loss = loss_fn(q_values, expected_q_values)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    if episode % update_target_freq == 0:
        target_net.load_state_dict(policy_net.state_dict())

    epsilon = max(epsilon_min, epsilon * epsilon_decay)
    print(f"Episode {episode + 1}/{num_episodes}, Score: {total_reward}, Epsilon: {epsilon:.2f}")

print("Training Complete!")
# Out:
# Episode 1/500, Score: 93, Epsilon: 0.99
# Episode 2/500, Score: 90, Epsilon: 0.99
# Episode 3/500, Score: 131, Epsilon: 0.99
# Episode 4/500, Score: 104, Epsilon: 0.98
# Episode 5/500, Score: 93, Epsilon: 0.98
# Episode 6/500, Score: 138, Epsilon: 0.97
# Episode 7/500, Score: 155, Epsilon: 0.97
# Episode 8/500, Score: 104, Epsilon: 0.96
# Episode 9/500, Score: 132, Epsilon: 0.96
# Episode 10/500, Score: 92, Epsilon: 0.95
# Episode 11/500, Score: 140, Epsilon: 0.95
# Episode 12/500, Score: 139, Epsilon: 0.94
# Episode 13/500, Score: 103, Epsilon: 0.94
# Episode 14/500, Score: 143, Epsilon: 0.93
# Episode 15/500, Score: 106, Epsilon: 0.93
# Episode 16/500, Score: 114, Epsilon: 0.92
# Episode 17/500, Score: 88, Epsilon: 0.92
# Episode 18/500, Score: 107, Epsilon: 0.91
# Episode 19/500, Score: 114, Epsilon: 0.91
# Episode 20/500, Score: 110, Epsilon: 0.90
# Episode 21/500, Score: 92, Epsilon: 0.90
# Episode 22/500, Score: 102, Epsilon: 0.90
# Episode 23/500, Score: 128, Epsilon: 0.89
# Episode 24/500, Score: 126, Epsilon: 0.89
# Episode 25/500, Score: 133, Epsilon: 0.88
# Episode 26/500, Score: 102, Epsilon: 0.88
# Episode 27/500, Score: 129, Epsilon: 0.87
# Episode 28/500, Score: 94, Epsilon: 0.87
# Episode 29/500, Score: 116, Epsilon: 0.86
# Episode 30/500, Score: 189, Epsilon: 0.86
# Episode 31/500, Score: 107, Epsilon: 0.86
# Episode 32/500, Score: 230, Epsilon: 0.85
# Episode 33/500, Score: 150, Epsilon: 0.85
# Episode 34/500, Score: 154, Epsilon: 0.84
# Episode 35/500, Score: 151, Epsilon: 0.84
# Episode 36/500, Score: 101, Epsilon: 0.83
# Episode 37/500, Score: 136, Epsilon: 0.83
# Episode 38/500, Score: 117, Epsilon: 0.83
# Episode 39/500, Score: 115, Epsilon: 0.82
# Episode 40/500, Score: 147, Epsilon: 0.82
# Episode 41/500, Score: 148, Epsilon: 0.81
# Episode 42/500, Score: 112, Epsilon: 0.81
# Episode 43/500, Score: 105, Epsilon: 0.81
# Episode 44/500, Score: 192, Epsilon: 0.80
# Episode 45/500, Score: 87, Epsilon: 0.80
# Episode 46/500, Score: 193, Epsilon: 0.79
# Episode 47/500, Score: 239, Epsilon: 0.79
# Episode 48/500, Score: 125, Epsilon: 0.79
# Episode 49/500, Score: 94, Epsilon: 0.78
# Episode 50/500, Score: 139, Epsilon: 0.78
# Episode 51/500, Score: 103, Epsilon: 0.77
# Episode 52/500, Score: 139, Epsilon: 0.77
# Episode 53/500, Score: 125, Epsilon: 0.77
# Episode 54/500, Score: 92, Epsilon: 0.76
# Episode 55/500, Score: 105, Epsilon: 0.76
# Episode 56/500, Score: 107, Epsilon: 0.76
# Episode 57/500, Score: 97, Epsilon: 0.75
# Episode 58/500, Score: 168, Epsilon: 0.75
# Episode 59/500, Score: 173, Epsilon: 0.74
# Episode 60/500, Score: 119, Epsilon: 0.74
# Episode 61/500, Score: 117, Epsilon: 0.74
# Episode 62/500, Score: 120, Epsilon: 0.73
# Episode 63/500, Score: 103, Epsilon: 0.73
# Episode 64/500, Score: 132, Epsilon: 0.73
# Episode 65/500, Score: 95, Epsilon: 0.72
# Episode 66/500, Score: 188, Epsilon: 0.72
# Episode 67/500, Score: 157, Epsilon: 0.71
# Episode 68/500, Score: 130, Epsilon: 0.71
# Episode 69/500, Score: 105, Epsilon: 0.71
# Episode 70/500, Score: 90, Epsilon: 0.70
# Episode 71/500, Score: 94, Epsilon: 0.70
# Episode 72/500, Score: 245, Epsilon: 0.70
# Episode 73/500, Score: 273, Epsilon: 0.69
# Episode 74/500, Score: 120, Epsilon: 0.69
# Episode 75/500, Score: 144, Epsilon: 0.69
# Episode 76/500, Score: 137, Epsilon: 0.68
# Episode 77/500, Score: 132, Epsilon: 0.68
# Episode 78/500, Score: 131, Epsilon: 0.68
# Episode 79/500, Score: 112, Epsilon: 0.67
# Episode 80/500, Score: 87, Epsilon: 0.67
# Episode 81/500, Score: 201, Epsilon: 0.67
# Episode 82/500, Score: 120, Epsilon: 0.66
# Episode 83/500, Score: 108, Epsilon: 0.66
# Episode 84/500, Score: 174, Epsilon: 0.66
# Episode 85/500, Score: 126, Epsilon: 0.65
# Episode 86/500, Score: 96, Epsilon: 0.65
# Episode 87/500, Score: 121, Epsilon: 0.65
# Episode 88/500, Score: 111, Epsilon: 0.64
# Episode 89/500, Score: 149, Epsilon: 0.64
# Episode 90/500, Score: 142, Epsilon: 0.64
# Episode 91/500, Score: 139, Epsilon: 0.63
# Episode 92/500, Score: 234, Epsilon: 0.63
# Episode 93/500, Score: 120, Epsilon: 0.63
# Episode 94/500, Score: 114, Epsilon: 0.62
# Episode 95/500, Score: 114, Epsilon: 0.62
# Episode 96/500, Score: 112, Epsilon: 0.62
# Episode 97/500, Score: 159, Epsilon: 0.61
# Episode 98/500, Score: 135, Epsilon: 0.61
# Episode 99/500, Score: 176, Epsilon: 0.61
# Episode 100/500, Score: 93, Epsilon: 0.61
# Episode 101/500, Score: 94, Epsilon: 0.60
# Episode 102/500, Score: 128, Epsilon: 0.60
# Episode 103/500, Score: 96, Epsilon: 0.60
# Episode 104/500, Score: 118, Epsilon: 0.59
# Episode 105/500, Score: 273, Epsilon: 0.59
# Episode 106/500, Score: 196, Epsilon: 0.59
# Episode 107/500, Score: 111, Epsilon: 0.58
# Episode 108/500, Score: 147, Epsilon: 0.58
# Episode 109/500, Score: 194, Epsilon: 0.58
# Episode 110/500, Score: 118, Epsilon: 0.58
# Episode 111/500, Score: 185, Epsilon: 0.57
# Episode 112/500, Score: 217, Epsilon: 0.57
# Episode 113/500, Score: 140, Epsilon: 0.57
# Episode 114/500, Score: 202, Epsilon: 0.56
# Episode 115/500, Score: 173, Epsilon: 0.56
# Episode 116/500, Score: 131, Epsilon: 0.56
# Episode 117/500, Score: 105, Epsilon: 0.56
# Episode 118/500, Score: 172, Epsilon: 0.55
# Episode 119/500, Score: 128, Epsilon: 0.55
# Episode 120/500, Score: 154, Epsilon: 0.55
# Episode 121/500, Score: 88, Epsilon: 0.55
# Episode 122/500, Score: 136, Epsilon: 0.54
# Episode 123/500, Score: 97, Epsilon: 0.54
# Episode 124/500, Score: 94, Epsilon: 0.54
# Episode 125/500, Score: 129, Epsilon: 0.53
# Episode 126/500, Score: 118, Epsilon: 0.53
# Episode 127/500, Score: 115, Epsilon: 0.53
# Episode 128/500, Score: 150, Epsilon: 0.53
# Episode 129/500, Score: 136, Epsilon: 0.52
# Episode 130/500, Score: 155, Epsilon: 0.52
# Episode 131/500, Score: 89, Epsilon: 0.52
# Episode 132/500, Score: 185, Epsilon: 0.52
# Episode 133/500, Score: 110, Epsilon: 0.51
# Episode 134/500, Score: 147, Epsilon: 0.51
# Episode 135/500, Score: 89, Epsilon: 0.51
# Episode 136/500, Score: 112, Epsilon: 0.51
# Episode 137/500, Score: 119, Epsilon: 0.50
# Episode 138/500, Score: 126, Epsilon: 0.50
# Episode 139/500, Score: 135, Epsilon: 0.50
# Episode 140/500, Score: 109, Epsilon: 0.50
# Episode 141/500, Score: 110, Epsilon: 0.49
# Episode 142/500, Score: 136, Epsilon: 0.49
# Episode 143/500, Score: 167, Epsilon: 0.49
# Episode 144/500, Score: 104, Epsilon: 0.49
# Episode 145/500, Score: 138, Epsilon: 0.48
# Episode 146/500, Score: 100, Epsilon: 0.48
# Episode 147/500, Score: 160, Epsilon: 0.48
# Episode 148/500, Score: 161, Epsilon: 0.48
# Episode 149/500, Score: 112, Epsilon: 0.47
# Episode 150/500, Score: 151, Epsilon: 0.47
# Episode 151/500, Score: 192, Epsilon: 0.47
# Episode 152/500, Score: 90, Epsilon: 0.47
# Episode 153/500, Score: 93, Epsilon: 0.46
# Episode 154/500, Score: 154, Epsilon: 0.46
# Episode 155/500, Score: 125, Epsilon: 0.46
# Episode 156/500, Score: 160, Epsilon: 0.46
# Episode 157/500, Score: 94, Epsilon: 0.46
# Episode 158/500, Score: 126, Epsilon: 0.45
# Episode 159/500, Score: 91, Epsilon: 0.45
# Episode 160/500, Score: 332, Epsilon: 0.45
# Episode 161/500, Score: 96, Epsilon: 0.45
# Episode 162/500, Score: 187, Epsilon: 0.44
# Episode 163/500, Score: 119, Epsilon: 0.44
# Episode 164/500, Score: 165, Epsilon: 0.44
# Episode 165/500, Score: 99, Epsilon: 0.44
# Episode 166/500, Score: 90, Epsilon: 0.44
# Episode 167/500, Score: 116, Epsilon: 0.43
# Episode 168/500, Score: 186, Epsilon: 0.43
# Episode 169/500, Score: 115, Epsilon: 0.43
# Episode 170/500, Score: 127, Epsilon: 0.43
# Episode 171/500, Score: 134, Epsilon: 0.42
# Episode 172/500, Score: 126, Epsilon: 0.42
# Episode 173/500, Score: 166, Epsilon: 0.42
# Episode 174/500, Score: 157, Epsilon: 0.42
# Episode 175/500, Score: 135, Epsilon: 0.42
# Episode 176/500, Score: 118, Epsilon: 0.41
# Episode 177/500, Score: 231, Epsilon: 0.41
# Episode 178/500, Score: 242, Epsilon: 0.41
# Episode 179/500, Score: 92, Epsilon: 0.41
# Episode 180/500, Score: 173, Epsilon: 0.41
# Episode 181/500, Score: 108, Epsilon: 0.40
# Episode 182/500, Score: 161, Epsilon: 0.40
# Episode 183/500, Score: 121, Epsilon: 0.40
# Episode 184/500, Score: 138, Epsilon: 0.40
# Episode 185/500, Score: 168, Epsilon: 0.40
# Episode 186/500, Score: 154, Epsilon: 0.39
# Episode 187/500, Score: 128, Epsilon: 0.39
# Episode 188/500, Score: 114, Epsilon: 0.39
# Episode 189/500, Score: 148, Epsilon: 0.39
# Episode 190/500, Score: 146, Epsilon: 0.39
# Episode 191/500, Score: 160, Epsilon: 0.38
# Episode 192/500, Score: 155, Epsilon: 0.38
# Episode 193/500, Score: 202, Epsilon: 0.38
# Episode 194/500, Score: 135, Epsilon: 0.38
# Episode 195/500, Score: 94, Epsilon: 0.38
# Episode 196/500, Score: 105, Epsilon: 0.37
# Episode 197/500, Score: 195, Epsilon: 0.37
# Episode 198/500, Score: 124, Epsilon: 0.37
# Episode 199/500, Score: 106, Epsilon: 0.37
# Episode 200/500, Score: 117, Epsilon: 0.37
# Episode 201/500, Score: 99, Epsilon: 0.37
# Episode 202/500, Score: 197, Epsilon: 0.36
# Episode 203/500, Score: 117, Epsilon: 0.36
# Episode 204/500, Score: 101, Epsilon: 0.36
# Episode 205/500, Score: 146, Epsilon: 0.36
# Episode 206/500, Score: 101, Epsilon: 0.36
# Episode 207/500, Score: 111, Epsilon: 0.35
# Episode 208/500, Score: 103, Epsilon: 0.35
# Episode 209/500, Score: 93, Epsilon: 0.35
# Episode 210/500, Score: 95, Epsilon: 0.35
# Episode 211/500, Score: 107, Epsilon: 0.35
# Episode 212/500, Score: 116, Epsilon: 0.35
# Episode 213/500, Score: 129, Epsilon: 0.34
# Episode 214/500, Score: 135, Epsilon: 0.34
# Episode 215/500, Score: 117, Epsilon: 0.34
# Episode 216/500, Score: 264, Epsilon: 0.34
# Episode 217/500, Score: 110, Epsilon: 0.34
# Episode 218/500, Score: 113, Epsilon: 0.34
# Episode 219/500, Score: 112, Epsilon: 0.33
# Episode 220/500, Score: 95, Epsilon: 0.33
# Episode 221/500, Score: 110, Epsilon: 0.33
# Episode 222/500, Score: 103, Epsilon: 0.33
# Episode 223/500, Score: 116, Epsilon: 0.33
# Episode 224/500, Score: 168, Epsilon: 0.33
# Episode 225/500, Score: 161, Epsilon: 0.32
# Episode 226/500, Score: 134, Epsilon: 0.32
# Episode 227/500, Score: 104, Epsilon: 0.32
# Episode 228/500, Score: 96, Epsilon: 0.32
# Episode 229/500, Score: 102, Epsilon: 0.32
# Episode 230/500, Score: 157, Epsilon: 0.32
# Episode 231/500, Score: 104, Epsilon: 0.31
# Episode 232/500, Score: 104, Epsilon: 0.31
# Episode 233/500, Score: 108, Epsilon: 0.31
# Episode 234/500, Score: 98, Epsilon: 0.31
# Episode 235/500, Score: 151, Epsilon: 0.31
# Episode 236/500, Score: 121, Epsilon: 0.31
# Episode 237/500, Score: 126, Epsilon: 0.30
# Episode 238/500, Score: 115, Epsilon: 0.30
# Episode 239/500, Score: 101, Epsilon: 0.30
# Episode 240/500, Score: 166, Epsilon: 0.30
# Episode 241/500, Score: 100, Epsilon: 0.30
# Episode 242/500, Score: 88, Epsilon: 0.30
# Episode 243/500, Score: 99, Epsilon: 0.30
# Episode 244/500, Score: 94, Epsilon: 0.29
# Episode 245/500, Score: 174, Epsilon: 0.29
# Episode 246/500, Score: 88, Epsilon: 0.29
# Episode 247/500, Score: 104, Epsilon: 0.29
# Episode 248/500, Score: 94, Epsilon: 0.29
# Episode 249/500, Score: 184, Epsilon: 0.29
# Episode 250/500, Score: 168, Epsilon: 0.29
# Episode 251/500, Score: 93, Epsilon: 0.28
# Episode 252/500, Score: 195, Epsilon: 0.28
# Episode 253/500, Score: 87, Epsilon: 0.28
# Episode 254/500, Score: 177, Epsilon: 0.28
# Episode 255/500, Score: 190, Epsilon: 0.28
# Episode 256/500, Score: 142, Epsilon: 0.28
# Episode 257/500, Score: 106, Epsilon: 0.28
# Episode 258/500, Score: 121, Epsilon: 0.27
# Episode 259/500, Score: 273, Epsilon: 0.27
# Episode 260/500, Score: 134, Epsilon: 0.27
# Episode 261/500, Score: 131, Epsilon: 0.27
# Episode 262/500, Score: 94, Epsilon: 0.27
# Episode 263/500, Score: 113, Epsilon: 0.27
# Episode 264/500, Score: 163, Epsilon: 0.27
# Episode 265/500, Score: 129, Epsilon: 0.26
# Episode 266/500, Score: 142, Epsilon: 0.26
# Episode 267/500, Score: 99, Epsilon: 0.26
# Episode 268/500, Score: 112, Epsilon: 0.26
# Episode 269/500, Score: 109, Epsilon: 0.26
# Episode 270/500, Score: 193, Epsilon: 0.26
# Episode 271/500, Score: 152, Epsilon: 0.26
# Episode 272/500, Score: 154, Epsilon: 0.26
# Episode 273/500, Score: 124, Epsilon: 0.25
# Episode 274/500, Score: 193, Epsilon: 0.25
# Episode 275/500, Score: 103, Epsilon: 0.25
# Episode 276/500, Score: 93, Epsilon: 0.25
# Episode 277/500, Score: 93, Epsilon: 0.25
# Episode 278/500, Score: 162, Epsilon: 0.25
# Episode 279/500, Score: 232, Epsilon: 0.25
# Episode 280/500, Score: 90, Epsilon: 0.25
# Episode 281/500, Score: 142, Epsilon: 0.24
# Episode 282/500, Score: 113, Epsilon: 0.24
# Episode 283/500, Score: 127, Epsilon: 0.24
# Episode 284/500, Score: 176, Epsilon: 0.24
# Episode 285/500, Score: 103, Epsilon: 0.24
# Episode 286/500, Score: 142, Epsilon: 0.24
# Episode 287/500, Score: 89, Epsilon: 0.24
# Episode 288/500, Score: 131, Epsilon: 0.24
# Episode 289/500, Score: 98, Epsilon: 0.23
# Episode 290/500, Score: 132, Epsilon: 0.23
# Episode 291/500, Score: 114, Epsilon: 0.23
# Episode 292/500, Score: 150, Epsilon: 0.23
# Episode 293/500, Score: 178, Epsilon: 0.23
# Episode 294/500, Score: 233, Epsilon: 0.23
# Episode 295/500, Score: 105, Epsilon: 0.23
# Episode 296/500, Score: 219, Epsilon: 0.23
# Episode 297/500, Score: 132, Epsilon: 0.23
# Episode 298/500, Score: 104, Epsilon: 0.22
# Episode 299/500, Score: 108, Epsilon: 0.22
# Episode 300/500, Score: 92, Epsilon: 0.22
# Episode 301/500, Score: 233, Epsilon: 0.22
# Episode 302/500, Score: 147, Epsilon: 0.22
# Episode 303/500, Score: 194, Epsilon: 0.22
# Episode 304/500, Score: 102, Epsilon: 0.22
# Episode 305/500, Score: 93, Epsilon: 0.22
# Episode 306/500, Score: 140, Epsilon: 0.22
# Episode 307/500, Score: 207, Epsilon: 0.21
# Episode 308/500, Score: 131, Epsilon: 0.21
# Episode 309/500, Score: 97, Epsilon: 0.21
# Episode 310/500, Score: 157, Epsilon: 0.21
# Episode 311/500, Score: 567, Epsilon: 0.21
# Episode 312/500, Score: 166, Epsilon: 0.21
# Episode 313/500, Score: 141, Epsilon: 0.21
# Episode 314/500, Score: 142, Epsilon: 0.21
# Episode 315/500, Score: 196, Epsilon: 0.21
# Episode 316/500, Score: 109, Epsilon: 0.21
# Episode 317/500, Score: 101, Epsilon: 0.20
# Episode 318/500, Score: 130, Epsilon: 0.20
# Episode 319/500, Score: 123, Epsilon: 0.20
# Episode 320/500, Score: 134, Epsilon: 0.20
# Episode 321/500, Score: 131, Epsilon: 0.20
# Episode 322/500, Score: 144, Epsilon: 0.20
# Episode 323/500, Score: 138, Epsilon: 0.20
# Episode 324/500, Score: 157, Epsilon: 0.20
# Episode 325/500, Score: 103, Epsilon: 0.20
# Episode 326/500, Score: 92, Epsilon: 0.20
# Episode 327/500, Score: 113, Epsilon: 0.19
# Episode 328/500, Score: 146, Epsilon: 0.19
# Episode 329/500, Score: 122, Epsilon: 0.19
# Episode 330/500, Score: 88, Epsilon: 0.19
# Episode 331/500, Score: 284, Epsilon: 0.19
# Episode 332/500, Score: 119, Epsilon: 0.19
# Episode 333/500, Score: 175, Epsilon: 0.19
# Episode 334/500, Score: 98, Epsilon: 0.19
# Episode 335/500, Score: 124, Epsilon: 0.19
# Episode 336/500, Score: 155, Epsilon: 0.19
# Episode 337/500, Score: 165, Epsilon: 0.18
# Episode 338/500, Score: 157, Epsilon: 0.18
# Episode 339/500, Score: 146, Epsilon: 0.18
# Episode 340/500, Score: 261, Epsilon: 0.18
# Episode 341/500, Score: 112, Epsilon: 0.18
# Episode 342/500, Score: 108, Epsilon: 0.18
# Episode 343/500, Score: 106, Epsilon: 0.18
# Episode 344/500, Score: 133, Epsilon: 0.18
# Episode 345/500, Score: 225, Epsilon: 0.18
# Episode 346/500, Score: 105, Epsilon: 0.18
# Episode 347/500, Score: 170, Epsilon: 0.18
# Episode 348/500, Score: 99, Epsilon: 0.17
# Episode 349/500, Score: 295, Epsilon: 0.17
# Episode 350/500, Score: 105, Epsilon: 0.17
# Episode 351/500, Score: 153, Epsilon: 0.17
# Episode 352/500, Score: 122, Epsilon: 0.17
# Episode 353/500, Score: 130, Epsilon: 0.17
# Episode 354/500, Score: 103, Epsilon: 0.17
# Episode 355/500, Score: 138, Epsilon: 0.17
# Episode 356/500, Score: 88, Epsilon: 0.17
# Episode 357/500, Score: 244, Epsilon: 0.17
# Episode 358/500, Score: 166, Epsilon: 0.17
# Episode 359/500, Score: 164, Epsilon: 0.17
# Episode 360/500, Score: 170, Epsilon: 0.16
# Episode 361/500, Score: 296, Epsilon: 0.16
# Episode 362/500, Score: 356, Epsilon: 0.16
# Episode 363/500, Score: 168, Epsilon: 0.16
# Episode 364/500, Score: 100, Epsilon: 0.16
# Episode 365/500, Score: 189, Epsilon: 0.16
# Episode 366/500, Score: 113, Epsilon: 0.16
# Episode 367/500, Score: 144, Epsilon: 0.16
# Episode 368/500, Score: 153, Epsilon: 0.16
# Episode 369/500, Score: 204, Epsilon: 0.16
# Episode 370/500, Score: 227, Epsilon: 0.16
# Episode 371/500, Score: 142, Epsilon: 0.16
# Episode 372/500, Score: 123, Epsilon: 0.15
# Episode 373/500, Score: 202, Epsilon: 0.15
# Episode 374/500, Score: 371, Epsilon: 0.15
# Episode 375/500, Score: 272, Epsilon: 0.15
# Episode 376/500, Score: 130, Epsilon: 0.15
# Episode 377/500, Score: 204, Epsilon: 0.15
# Episode 378/500, Score: 160, Epsilon: 0.15
# Episode 379/500, Score: 142, Epsilon: 0.15
# Episode 380/500, Score: 108, Epsilon: 0.15
# Episode 381/500, Score: 180, Epsilon: 0.15
# Episode 382/500, Score: 91, Epsilon: 0.15
# Episode 383/500, Score: 90, Epsilon: 0.15
# Episode 384/500, Score: 103, Epsilon: 0.15
# Episode 385/500, Score: 147, Epsilon: 0.15
# Episode 386/500, Score: 123, Epsilon: 0.14
# Episode 387/500, Score: 117, Epsilon: 0.14
# Episode 388/500, Score: 91, Epsilon: 0.14
# Episode 389/500, Score: 125, Epsilon: 0.14
# Episode 390/500, Score: 145, Epsilon: 0.14
# Episode 391/500, Score: 176, Epsilon: 0.14
# Episode 392/500, Score: 98, Epsilon: 0.14
# Episode 393/500, Score: 170, Epsilon: 0.14
# Episode 394/500, Score: 97, Epsilon: 0.14
# Episode 395/500, Score: 151, Epsilon: 0.14
# Episode 396/500, Score: 297, Epsilon: 0.14
# Episode 397/500, Score: 113, Epsilon: 0.14
# Episode 398/500, Score: 160, Epsilon: 0.14
# Episode 399/500, Score: 92, Epsilon: 0.14
# Episode 400/500, Score: 203, Epsilon: 0.13
# Episode 401/500, Score: 146, Epsilon: 0.13
# Episode 402/500, Score: 272, Epsilon: 0.13
# Episode 403/500, Score: 179, Epsilon: 0.13
# Episode 404/500, Score: 106, Epsilon: 0.13
# Episode 405/500, Score: 96, Epsilon: 0.13
# Episode 406/500, Score: 90, Epsilon: 0.13
# Episode 407/500, Score: 118, Epsilon: 0.13
# Episode 408/500, Score: 105, Epsilon: 0.13
# Episode 409/500, Score: 90, Epsilon: 0.13
# Episode 410/500, Score: 100, Epsilon: 0.13
# Episode 411/500, Score: 113, Epsilon: 0.13
# Episode 412/500, Score: 128, Epsilon: 0.13
# Episode 413/500, Score: 152, Epsilon: 0.13
# Episode 414/500, Score: 114, Epsilon: 0.13
# Episode 415/500, Score: 98, Epsilon: 0.12
# Episode 416/500, Score: 153, Epsilon: 0.12
# Episode 417/500, Score: 89, Epsilon: 0.12
# Episode 418/500, Score: 100, Epsilon: 0.12
# Episode 419/500, Score: 169, Epsilon: 0.12
# Episode 420/500, Score: 117, Epsilon: 0.12
# Episode 421/500, Score: 104, Epsilon: 0.12
# Episode 422/500, Score: 99, Epsilon: 0.12
# Episode 423/500, Score: 109, Epsilon: 0.12
# Episode 424/500, Score: 136, Epsilon: 0.12
# Episode 425/500, Score: 161, Epsilon: 0.12
# Episode 426/500, Score: 228, Epsilon: 0.12
# Episode 427/500, Score: 102, Epsilon: 0.12
# Episode 428/500, Score: 133, Epsilon: 0.12
# Episode 429/500, Score: 93, Epsilon: 0.12
# Episode 430/500, Score: 99, Epsilon: 0.12
# Episode 431/500, Score: 166, Epsilon: 0.12
# Episode 432/500, Score: 256, Epsilon: 0.11
# Episode 433/500, Score: 143, Epsilon: 0.11
# Episode 434/500, Score: 111, Epsilon: 0.11
# Episode 435/500, Score: 250, Epsilon: 0.11
# Episode 436/500, Score: 160, Epsilon: 0.11
# Episode 437/500, Score: 158, Epsilon: 0.11
# Episode 438/500, Score: 288, Epsilon: 0.11
# Episode 439/500, Score: 170, Epsilon: 0.11
# Episode 440/500, Score: 290, Epsilon: 0.11
# Episode 441/500, Score: 87, Epsilon: 0.11
# Episode 442/500, Score: 107, Epsilon: 0.11
# Episode 443/500, Score: 157, Epsilon: 0.11
# Episode 444/500, Score: 104, Epsilon: 0.11
# Episode 445/500, Score: 132, Epsilon: 0.11
# Episode 446/500, Score: 147, Epsilon: 0.11
# Episode 447/500, Score: 155, Epsilon: 0.11
# Episode 448/500, Score: 146, Epsilon: 0.11
# Episode 449/500, Score: 98, Epsilon: 0.11
# Episode 450/500, Score: 164, Epsilon: 0.10
# Episode 451/500, Score: 153, Epsilon: 0.10
# Episode 452/500, Score: 108, Epsilon: 0.10
# Episode 453/500, Score: 240, Epsilon: 0.10
# Episode 454/500, Score: 163, Epsilon: 0.10
# Episode 455/500, Score: 125, Epsilon: 0.10
# Episode 456/500, Score: 149, Epsilon: 0.10
# Episode 457/500, Score: 134, Epsilon: 0.10
# Episode 458/500, Score: 164, Epsilon: 0.10
# Episode 459/500, Score: 495, Epsilon: 0.10
# Episode 460/500, Score: 108, Epsilon: 0.10
# Episode 461/500, Score: 225, Epsilon: 0.10
# Episode 462/500, Score: 141, Epsilon: 0.10
# Episode 463/500, Score: 197, Epsilon: 0.10
# Episode 464/500, Score: 108, Epsilon: 0.10
# Episode 465/500, Score: 188, Epsilon: 0.10
# Episode 466/500, Score: 263, Epsilon: 0.10
# Episode 467/500, Score: 140, Epsilon: 0.10
# Episode 468/500, Score: 180, Epsilon: 0.10
# Episode 469/500, Score: 114, Epsilon: 0.10
# Episode 470/500, Score: 135, Epsilon: 0.09
# Episode 471/500, Score: 146, Epsilon: 0.09
# Episode 472/500, Score: 145, Epsilon: 0.09
# Episode 473/500, Score: 171, Epsilon: 0.09
# Episode 474/500, Score: 258, Epsilon: 0.09
# Episode 475/500, Score: 467, Epsilon: 0.09
# Episode 476/500, Score: 114, Epsilon: 0.09
# Episode 477/500, Score: 176, Epsilon: 0.09
# Episode 478/500, Score: 101, Epsilon: 0.09
# Episode 479/500, Score: 144, Epsilon: 0.09
# Episode 480/500, Score: 219, Epsilon: 0.09
# Episode 481/500, Score: 153, Epsilon: 0.09
# Episode 482/500, Score: 98, Epsilon: 0.09
# Episode 483/500, Score: 365, Epsilon: 0.09
# Episode 484/500, Score: 105, Epsilon: 0.09
# Episode 485/500, Score: 159, Epsilon: 0.09
# Episode 486/500, Score: 114, Epsilon: 0.09
# Episode 487/500, Score: 245, Epsilon: 0.09
# Episode 488/500, Score: 153, Epsilon: 0.09
# Episode 489/500, Score: 108, Epsilon: 0.09
# Episode 490/500, Score: 340, Epsilon: 0.09
# Episode 491/500, Score: 179, Epsilon: 0.09
# Episode 492/500, Score: 145, Epsilon: 0.08
# Episode 493/500, Score: 137, Epsilon: 0.08
# Episode 494/500, Score: 128, Epsilon: 0.08
# Episode 495/500, Score: 158, Epsilon: 0.08
# Episode 496/500, Score: 185, Epsilon: 0.08
# Episode 497/500, Score: 146, Epsilon: 0.08
# Episode 498/500, Score: 112, Epsilon: 0.08
# Episode 499/500, Score: 92, Epsilon: 0.08
# Episode 500/500, Score: 121, Epsilon: 0.08
# Training Complete!

# %%
env = DodgeGame()
state = env.reset()
done = False

while not done:
    env.render()  # Show the game
    with torch.no_grad():
        action = policy_net(state).argmax().item()
    state, _, done = env.step(action)

# %%
import matplotlib.pyplot as plt
from IPython.display import display, clear_output
import time

def play_trained_agent(policy_net, env, num_episodes=3):
    for episode in range(num_episodes):
        state = env.reset()
        done = False
        total_reward = 0

        while not done:
            with torch.no_grad():
                action = policy_net(state).argmax().item()

            state, reward, done = env.step(action)
            total_reward += reward

            # ✅ Render the game as an image
            env.render()
            frame = pygame.surfarray.array3d(screen)  # Get game screen as an array
            frame = frame.swapaxes(0, 1)  # Adjust format for display

            plt.imshow(frame)
            plt.axis("off")
            clear_output(wait=True)
            display(plt.gcf())
            time.sleep(0.05)  # Adjust speed

        print(f"Episode {episode + 1} finished with total reward: {total_reward}")

# ✅ Run this to see the trained agent play the game
play_trained_agent(policy_net, env)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-bff6e051e542> in <cell line: 0>()
#      30
#      31 # ✅ Run this to see the trained agent play the game
# ---> 32 play_trained_agent(policy_net, env)
#
# <ipython-input-30-bff6e051e542> in play_trained_agent(policy_net, env, num_episodes)
#      24             plt.axis("off")
#      25             clear_output(wait=True)
# ---> 26             display(plt.gcf())
#      27             time.sleep(0.05)  # Adjust speed
#      28
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2182                 # force the figure dpi to 72), so we need to set it again here.
#    2183                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2184                     result = print_method(
#    2185                         filename,
#    2186                         facecolor=facecolor,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backend_bases.py in <lambda>(*args, **kwargs)
#    2038                 "bbox_inches_restore"}
#    2039             skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2040             print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2041                 *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2042         else:  # Let third-parties do as they see fit.
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs)
#     479             *metadata*, including the default 'Software' key.
#     480         """
# --> 481         self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#     482
#     483     def print_to_buffer(self):
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backends/backend_agg.py in _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     427         *pil_kwargs* and *metadata* are forwarded).
#     428         """
# --> 429         FigureCanvasAgg.draw(self)
#     430         mpl.image.imsave(
#     431             filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     380         with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     381               else nullcontext()):
# --> 382             self.figure.draw(self.renderer)
#     383             # A GUI class may be need to update a window using this draw, so
#     384             # don't forget to call the superclass.
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      92     @wraps(draw)
#      93     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94         result = draw(artist, renderer, *args, **kwargs)
#      95         if renderer._rasterizing:
#      96             renderer.stop_rasterizing()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    3255
#    3256                 self.patch.draw(renderer)
# -> 3257                 mimage._draw_list_compositing_images(
#    3258                     renderer, self, artists, self.suppressComposite)
#    3259
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132     if not_composite or not has_images:
#     133         for a in artists:
# --> 134             a.draw(renderer)
#     135     else:
#     136         # Composite any adjacent images together
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3179             _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
#    3180
# -> 3181         mimage._draw_list_compositing_images(
#    3182             renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3183
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132     if not_composite or not has_images:
#     133         for a in artists:
# --> 134             a.draw(renderer)
#     135     else:
#     136         # Composite any adjacent images together
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in draw(self, renderer)
#     597                 renderer.draw_image(gc, l, b, im, trans)
#     598         else:
# --> 599             im, l, b, trans = self.make_image(
#     600                 renderer, renderer.get_image_magnification())
#     601             if im is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in make_image(self, renderer, magnification, unsampled)
#     900         clip = ((self.get_clip_box() or self.axes.bbox) if self.get_clip_on()
#     901                 else self.get_figure(root=True).bbox)
# --> 902         return self._make_image(self._A, bbox, transformed_bbox, clip,
#     903                                 magnification, unsampled=unsampled)
#     904
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in _make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     511                     output_alpha = _resample(  # resample alpha channel
#     512                         self, A[..., 3], out_shape, t, alpha=alpha)
# --> 513                 output = _resample(  # resample rgb channels
#     514                     self, _rgb_to_rgba(A[..., :3]), out_shape, t, alpha=alpha)
#     515                 output[..., 3] = output_alpha  # recombine rgb and alpha
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in _resample(image_obj, data, out_shape, transform, resample, alpha)
#     193         # if zooming in more than a factor of 3
#     194         pos = np.array([[0, 0], [data.shape[1], data.shape[0]]])
# --> 195         disp = transform.transform(pos)
#     196         dispx = np.abs(np.diff(disp[:, 0]))
#     197         dispy = np.abs(np.diff(disp[:, 1]))
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/transforms.py in transform(self, values)
#    1493
#    1494         # Transform the values
# -> 1495         res = self.transform_affine(self.transform_non_affine(values))
#    1496
#    1497         # Convert the result back to the shape of the input values.
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/transforms.py in transform_affine(self, values)
#    2408     def transform_affine(self, values):
#    2409         # docstring inherited
# -> 2410         return self.get_affine().transform(values)
#    2411
#    2412     def transform_non_affine(self, values):
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/transforms.py in get_affine(self)
#    2434             return self._b.get_affine()
#    2435         else:
# -> 2436             return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2437                                    self._a.get_affine().get_matrix()))
#    2438
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x79dd16babf60> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     124             # ignore the tracking, just draw and close all figures
#     125             try:
# --> 126                 return show(True)
#     127             except Exception as e:
#     128                 # safely show traceback if in IPython, else raise
#
# /usr/local/lib/python3.11/dist-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
#      92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2153                 # so that we can inject the orientation
#    2154                 with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2155                     self.figure.draw(renderer)
#    2156             if bbox_inches:
#    2157                 if bbox_inches == "tight":
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      92     @wraps(draw)
#      93     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94         result = draw(artist, renderer, *args, **kwargs)
#      95         if renderer._rasterizing:
#      96             renderer.stop_rasterizing()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    3255
#    3256                 self.patch.draw(renderer)
# -> 3257                 mimage._draw_list_compositing_images(
#    3258                     renderer, self, artists, self.suppressComposite)
#    3259
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132     if not_composite or not has_images:
#     133         for a in artists:
# --> 134             a.draw(renderer)
#     135     else:
#     136         # Composite any adjacent images together
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3179             _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
#    3180
# -> 3181         mimage._draw_list_compositing_images(
#    3182             renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3183
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132     if not_composite or not has_images:
#     133         for a in artists:
# --> 134             a.draw(renderer)
#     135     else:
#     136         # Composite any adjacent images together
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in draw(self, renderer)
#     597                 renderer.draw_image(gc, l, b, im, trans)
#     598         else:
# --> 599             im, l, b, trans = self.make_image(
#     600                 renderer, renderer.get_image_magnification())
#     601             if im is not None:
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in make_image(self, renderer, magnification, unsampled)
#     900         clip = ((self.get_clip_box() or self.axes.bbox) if self.get_clip_on()
#     901                 else self.get_figure(root=True).bbox)
# --> 902         return self._make_image(self._A, bbox, transformed_bbox, clip,
#     903                                 magnification, unsampled=unsampled)
#     904
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in _make_image(self, A, in_bbox, out_bbox, clip_bbox, magnification, unsampled, round_to_pixel_border)
#     511                     output_alpha = _resample(  # resample alpha channel
#     512                         self, A[..., 3], out_shape, t, alpha=alpha)
# --> 513                 output = _resample(  # resample rgb channels
#     514                     self, _rgb_to_rgba(A[..., :3]), out_shape, t, alpha=alpha)
#     515                 output[..., 3] = output_alpha  # recombine rgb and alpha
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in _resample(image_obj, data, out_shape, transform, resample, alpha)
#     208     if resample is None:
#     209         resample = image_obj.get_resample()
# --> 210     _image.resample(data, out, transform,
#     211                     _interpd_[interpolation],
#     212                     resample,
#
# KeyboardInterrupt:

# %%
torch.save(policy_net.state_dict(), "dodge_blocks_dqn.pth")

# %%
import torch

# Load the trained model
policy_net.load_state_dict(torch.load("dodge_blocks_dqn.pth"))
policy_net.eval()  # Set model to evaluation mode
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9b3b43710772> in <cell line: 0>()
#       2
#       3 # Load the trained model
# ----> 4 policy_net.load_state_dict(torch.load("dodge_blocks_dqn.pth"))
#       5 policy_net.eval()  # Set model to evaluation mode
#
# NameError: name 'policy_net' is not defined

# %%
import matplotlib.pyplot as plt
from IPython.display import display, clear_output
import time

def play_trained_agent(policy_net, env, num_episodes=3):
    for episode in range(num_episodes):
        state = env.reset()
        done = False
        total_reward = 0

        while not done:
            with torch.no_grad():
                action = policy_net(state).argmax().item()

            state, reward, done = env.step(action)
            total_reward += reward

            # ✅ Render the game as an image
            env.render()
            frame = pygame.surfarray.array3d(screen)  # Get game screen as an array
            frame = frame.swapaxes(0, 1)  # Adjust format for display

            plt.imshow(frame)
            plt.axis("off")
            clear_output(wait=True)
            display(plt.gcf())
            time.sleep(0.05)  # Adjust speed

        print(f"Episode {episode + 1} finished with total reward: {total_reward}")

# ✅ Run the trained agent
play_trained_agent(policy_net, env)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0506d14fe002> in <cell line: 0>()
#      30
#      31 # ✅ Run the trained agent
# ---> 32 play_trained_agent(policy_net, env)
#
# NameError: name 'policy_net' is not defined
